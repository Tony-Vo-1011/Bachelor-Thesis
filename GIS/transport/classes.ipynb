# %%
import pandas as pd

lst = ['cycling', 'driving', 'walking']
lst_1 = ['cycle', 'drive', 'walk']
base = 'C:/Users/15177459/Desktop/gis_outputs/cost_od_matrix/transport/output/'

for i in range(len(lst)):
    a = pd.read_csv(base + f'ODMatrix_buurtbuurt_{lst_1[i]}.csv')
    summary = a["mean"]
    print(f"{lst[i].upper()}")
    print(summary.describe())
    print(summary.quantile([0.25, 0.5, 0.75, 0.9, 0.95, 1.0]))
# Out:
# CYCLING
# count    517.000000
# mean      28.519757
# std       10.419036
# min        0.000000
# 25%       22.004416
# 50%       25.191101
# 75%       32.825379
# max       69.501917
# Name: mean, dtype: float64
# 0.25    22.004416
# 0.50    25.191101
# 0.75    32.825379
# 0.90    44.295478
# 0.95    50.119922
# 1.00    69.501917
# Name: mean, dtype: float64
# DRIVING
# count    517.000000
# mean       8.668601
# std        2.162577
# min        0.000000
# 25%        7.501719
# 50%        8.165984
# 75%        9.730028
# max       19.692870
# Name: mean, dtype: float64
# 0.25     7.501719
# 0.50     8.165984
# 0.75     9.730028
# 0.90    10.988659
# 0.95    12.005636
# 1.00    19.692870
# Name: mean, dtype: float64
# WALKING
# count    517.000000
# mean      85.354403
# std       31.290628
# min        0.000000
# 25%       65.689855
# 50%       75.486337
# 75%       98.353516
# max      208.404867
# Name: mean, dtype: float64
# 0.25     65.689855
# 0.50     75.486337
# ...
